# %% [markdown]
# ## EDA = Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import os
import warnings; warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px

# %%
os.listdir('../data/raw/')
# Out:
# ['12_apple_global_sales_dataset.csv']

# %%
df = pd.read_csv('../data/raw/12_apple_global_sales_dataset.csv')

# %%
df.sample(2)
# Out:
#             sale_id   sale_date  year quarter      month  country  region  \
# 9549  APPL-00009550  2024-09-02  2024      Q3  September   Sweden  Europe
# 3097  APPL-00003098  2022-12-12  2022      Q4   December  Finland  Europe
#
#         city           product_name category  ... currency fx_rate_to_usd  \
# 9549  Örebro      iPhone 13 Pro Max   iPhone  ...      SEK          10.55
# 3097    Oulu  AirPods Pro (2nd Gen)  AirPods  ...      EUR           0.92
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 9549                23642.97    Apple Store            Cash         Education
# 3097                  191.31    Apple Store       Apple Pay          Business
#
#       customer_age_group previous_device_os  customer_rating  return_status
# 9549               18–24             iOS 17              5.0       Returned
# 3097                 55+                NaN              NaN           Kept
#
# [2 rows x 27 columns]

# %%
df.drop('sale_id', axis= 1 , inplace=True)

# %%
df.sample(1)
# Out:
#        sale_date  year quarter     month      country region     city  \
# 8974  2024-11-17  2024      Q4  November  South Korea   Asia  Incheon
#
#                product_name category storage  ... currency  fx_rate_to_usd  \
# 8974  AirPods Pro (2nd Gen)  AirPods     NaN  ...      KRW          1328.0
#
#       revenue_local_currency    sales_channel  payment_method  \
# 8974               309716.16  Corporate / B2B       Gift Card
#
#       customer_segment customer_age_group  previous_device_os  \
# 8974        Individual              18–24                 NaN
#
#       customer_rating return_status
# 8974              4.1          Kept
#
# [1 rows x 26 columns]

# %%
df.isna().sum()
# Out:
# sale_date                    0
# year                         0
# quarter                      0
# month                        0
# country                      0
# region                       0
# city                         0
# product_name                 0
# category                     0
# storage                   4804
# color                        0
# unit_price_usd               0
# discount_pct                 0
# units_sold                   0
# discounted_price_usd         0
# revenue_usd                  0
# currency                     0
# fx_rate_to_usd               0
# revenue_local_currency       0
# sales_channel                0
# payment_method               0
# customer_segment             0
# customer_age_group           0
# previous_device_os        8056
# customer_rating           3360
# return_status                0
# dtype: int64

# %% [markdown]
# # Storage

# %%
df["storage"].value_counts()
# Out:
# storage
# 64 GB         944
# 256 GB        941
# 512 GB        924
# 128 GB        903
# 1 TB          889
# 1 TB SSD      473
# 2 TB SSD      472
# 512 GB SSD    471
# 256 GB SSD    457
# 2 TB          222
# Name: count, dtype: int64

# %%
df["storage"].unique()
# Out:
# <ArrowStringArray>
# [         nan,   '1 TB SSD',      '64 GB',     '128 GB',     '256 GB',
#        '1 TB',   '2 TB SSD',     '512 GB', '512 GB SSD',       '2 TB',
#  '256 GB SSD']
# Length: 11, dtype: str

# %%
df[ df["storage"].isna()].sample(5)
# Out:
#        sale_date  year quarter      month       country  region          city  \
# 8487  2023-12-12  2023      Q4   December     Singapore    Asia     Singapore
# 8391  2022-07-08  2022      Q3       July     Singapore    Asia     Singapore
# 8593  2024-02-09  2024      Q1   February  South Africa  Africa  Bloemfontein
# 4350  2023-09-29  2023      Q3  September     Indonesia    Asia      Surabaya
# 3253  2024-01-19  2024      Q1    January        France  Europe         Lille
#
#                product_name     category storage  ... currency  \
# 8487    Apple Watch Ultra 2  Apple Watch     NaN  ...      SGD
# 8391   Apple Watch Series 9  Apple Watch     NaN  ...      SGD
# 8593            Magic Mouse  Accessories     NaN  ...      ZAR
# 4350  AirPods Pro (2nd Gen)      AirPods     NaN  ...      IDR
# 3253         Magic Trackpad  Accessories     NaN  ...      EUR
#
#       fx_rate_to_usd  revenue_local_currency        sales_channel  \
# ...

# %% [markdown]
# # previous_device_os

# %%
df["previous_device_os"].unique()
# Out:
# <ArrowStringArray>
# [nan, 'iOS 16', 'New User', 'Other', 'iOS 15', 'Android', 'iOS 17']
# Length: 7, dtype: str

# %%
df["previous_device_os"].value_counts()
# Out:
# previous_device_os
# Android     595
# iOS 16      587
# Other       581
# New User    571
# iOS 15      556
# iOS 17      554
# Name: count, dtype: int64

# %%
df[ df["previous_device_os"].isna()].sample(10)
# Out:
#         sale_date  year quarter      month        country         region  \
# 3932   2024-02-16  2024      Q1   February      Hong Kong           Asia
# 8046   2024-07-20  2024      Q3       July         Russia    Europe/Asia
# 880    2023-02-21  2023      Q1   February     Bangladesh           Asia
# 4106   2022-10-29  2022      Q4    October          India           Asia
# 11213  2022-12-20  2022      Q4   December  United States  North America
# 6035   2023-05-10  2023      Q2        May    Netherlands         Europe
# 4285   2022-09-23  2022      Q3  September      Indonesia           Asia
# 5185   2022-04-04  2022      Q2      April          Kenya         Africa
# 4864   2023-02-27  2023      Q1   February          Italy         Europe
# 7821   2022-05-03  2022      Q2        May       Portugal         Europe
#
#                city              product_name     category   storage  ...  \
# 3932      Yuen Long  Apple Watch SE (2nd Gen)  Apple Watch       NaN  ...
# ...
