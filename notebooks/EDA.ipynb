# %% [markdown]
# ## EDA = Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import os
import warnings; warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px
# pip install streamlit-option-menu
# from streamlit_option_menu import option_menu

# %%
os.listdir('../data/raw/')
# Out:
# ['12_apple_global_sales_dataset.csv']

# %%
df = pd.read_csv('../data/raw/12_apple_global_sales_dataset.csv')

# %%
df.shape
# Out:
# (11500, 27)

# %%
df.sample(2)
# Out:
#             sale_id   sale_date  year quarter      month    country region  \
# 4025  APPL-00004026  2023-02-21  2023      Q1   February      India   Asia
# 4192  APPL-00004193  2023-09-19  2023      Q3  September  Indonesia   Asia
#
#         city    product_name category  ... currency fx_rate_to_usd  \
# 4025  Kanpur  iPhone 13 Mini   iPhone  ...      INR           83.5
# 4192  Bekasi       iPhone 13   iPhone  ...      IDR        15700.0
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 4025                53880.88    Apple Store     Net Banking        Government
# 4192             10692485.00  Carrier Store       Gift Card        Individual
#
#       customer_age_group previous_device_os  customer_rating  return_status
# 4025               35–44            Android              3.5           Kept
# 4192               18–24             iOS 16              3.6           Kept
#
# [2 rows x 27 columns]

# %%
df.drop('sale_id', axis= 1 , inplace=True)

# %%
df.sample(1)
# Out:
#       sale_date  year quarter    month    country   region       city  \
# 451  2022-10-21  2022      Q4  October  Australia  Oceania  Newcastle
#
#               product_name     category storage  ... currency  fx_rate_to_usd  \
# 451  Apple TV 4K (3rd Gen)  Accessories     NaN  ...      AUD            1.53
#
#      revenue_local_currency    sales_channel  payment_method  \
# 451                  336.57  Corporate / B2B       Gift Card
#
#      customer_segment customer_age_group  previous_device_os  customer_rating  \
# 451         Education                55+                 NaN              3.6
#
#     return_status
# 451          Kept
#
# [1 rows x 26 columns]

# %%
df.isna().sum()
# Out:
# sale_date                    0
# year                         0
# quarter                      0
# month                        0
# country                      0
# region                       0
# city                         0
# product_name                 0
# category                     0
# storage                   4804
# color                        0
# unit_price_usd               0
# discount_pct                 0
# units_sold                   0
# discounted_price_usd         0
# revenue_usd                  0
# currency                     0
# fx_rate_to_usd               0
# revenue_local_currency       0
# sales_channel                0
# payment_method               0
# customer_segment             0
# customer_age_group           0
# previous_device_os        8056
# customer_rating           3360
# return_status                0
# dtype: int64

# %% [markdown]
# # Storage

# %%
df["storage"].value_counts()
# Out:
# storage
# 64 GB         944
# 256 GB        941
# 512 GB        924
# 128 GB        903
# 1 TB          889
# 1 TB SSD      473
# 2 TB SSD      472
# 512 GB SSD    471
# 256 GB SSD    457
# 2 TB          222
# Name: count, dtype: int64

# %%
df["storage"].unique()
# Out:
# array([nan, '1 TB SSD', '64 GB', '128 GB', '256 GB', '1 TB', '2 TB SSD',
#        '512 GB', '512 GB SSD', '2 TB', '256 GB SSD'], dtype=object)

# %%
df["storage"].isna().sum()
# Out:
# np.int64(4804)

# %% [markdown]
# # previous_device_os

# %%
df["previous_device_os"].unique()
# Out:
# array([nan, 'iOS 16', 'New User', 'Other', 'iOS 15', 'Android', 'iOS 17'],
#       dtype=object)

# %%
df["previous_device_os"].value_counts()
# Out:
# previous_device_os
# Android     595
# iOS 16      587
# Other       581
# New User    571
# iOS 15      556
# iOS 17      554
# Name: count, dtype: int64

# %%
df[ df["previous_device_os"].isna()].sample(10)
# Out:
#         sale_date  year quarter     month      country         region  \
# 7393   2022-02-14  2022      Q1  February       Poland         Europe
# 1946   2024-06-18  2024      Q2      June        Chile  South America
# 10580  2024-04-08  2024      Q2     April          UAE    Middle East
# 6613   2023-10-29  2023      Q4   October      Nigeria         Africa
# 8091   2024-03-24  2024      Q1     March       Russia    Europe/Asia
# 7959   2024-02-03  2024      Q1  February       Russia    Europe/Asia
# 3559   2023-01-14  2023      Q1   January      Germany         Europe
# 5977   2024-10-01  2024      Q4   October  Netherlands         Europe
# 10603  2022-11-14  2022      Q4  November          UAE    Middle East
# 445    2022-01-16  2022      Q1   January    Australia        Oceania
#
#                 city                  product_name     category     storage  \
# 7393          Gdansk         iPad Pro 11-inch (M2)         iPad      128 GB
# ...

# %% [markdown]
# # customer_rating

# %%
df["customer_rating"].value_counts()
# Out:
# customer_rating
# 4.0    434
# 4.4    433
# 4.6    433
# 3.7    432
# 3.2    428
# 4.2    426
# 3.4    422
# 4.8    414
# 4.3    413
# 3.5    407
# 4.1    405
# 3.9    399
# 3.6    399
# 3.3    398
# 4.7    394
# 4.9    393
# 3.8    376
# 3.1    373
# 4.5    366
# 3.0    198
# 5.0    197
# Name: count, dtype: int64

# %%
df ["customer_rating"].isna().sum()
# Out:
# np.int64(3360)

# %%
df[ df ["customer_rating"].isna()].sample(10)
# Out:
#         sale_date  year quarter     month        country         region  \
# 5276   2022-02-25  2022      Q1  February          Kenya         Africa
# 8807   2022-05-17  2022      Q2       May    South Korea           Asia
# 9680   2023-08-06  2023      Q3    August    Switzerland         Europe
# 9169   2024-12-28  2024      Q4  December          Spain         Europe
# 7866   2022-08-17  2022      Q3    August         Russia    Europe/Asia
# 2863   2023-05-15  2023      Q2       May          Egypt         Africa
# 8563   2024-10-29  2024      Q4   October      Singapore           Asia
# 146    2023-11-09  2023      Q4  November      Argentina  South America
# 5150   2022-01-04  2022      Q1   January          Kenya         Africa
# 11223  2024-10-29  2024      Q4   October  United States  North America
#
#                    city                  product_name     category  \
# 5276            Mombasa                 iPhone 14 Pro       iPhone
# ...

# %% [markdown]
# # Duplicated

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample(1)
# Out:
#        sale_date  year quarter     month country region    city  \
# 4014  2022-12-30  2022      Q4  December   India   Asia  Jaipur
#
#              product_name category storage  ... currency  fx_rate_to_usd  \
# 4014  iPhone SE (3rd Gen)   iPhone    1 TB  ...      INR            83.5
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 4014                33197.93  Carrier Store       Apple Pay        Government
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 4014              18–24              iOS 17              NaN          Kept
#
# [1 rows x 26 columns]

# %%
df["sale_date"].unique()
# Out:
# array(['2022-01-03', '2022-01-04', '2022-05-18', ..., '2024-04-06',
#        '2024-03-13', '2024-08-12'], shape=(1096,), dtype=object)

# %%
df.columns
# Out:
# Index(['sale_date', 'year', 'quarter', 'month', 'country', 'region', 'city',
#        'product_name', 'category', 'storage', 'color', 'unit_price_usd',
#        'discount_pct', 'units_sold', 'discounted_price_usd', 'revenue_usd',
#        'currency', 'fx_rate_to_usd', 'revenue_local_currency', 'sales_channel',
#        'payment_method', 'customer_segment', 'customer_age_group',
#        'previous_device_os', 'customer_rating', 'return_status'],
#       dtype='object')

# %% [markdown]
# # Year 2022
# - Q1
# - Q2
# - Q3
# - Q4

# %% [markdown]
# # Start Here

# %%
All_Sales_price = round(df["unit_price_usd"].sum())
All_orders = df.shape[0]

All_Sales_price, All_orders
# Out:
# (9290289, 11500)

# %%
year2022 = df [df['year'] == 2022]

year2022
# Out:
#         sale_date  year quarter    month    country         region  \
# 0      2022-01-03  2022      Q1  January  Argentina  South America
# 1      2022-01-04  2022      Q1  January  Argentina  South America
# 2      2022-05-18  2022      Q2      May  Argentina  South America
# 3      2022-05-23  2022      Q2      May  Argentina  South America
# 4      2022-07-13  2022      Q3     July  Argentina  South America
# ...           ...   ...     ...      ...        ...            ...
# 11476  2022-06-02  2022      Q2     June    Vietnam           Asia
# 11477  2022-07-01  2022      Q3     July    Vietnam           Asia
# 11478  2022-07-09  2022      Q3     July    Vietnam           Asia
# 11479  2022-07-15  2022      Q3     July    Vietnam           Asia
# 11480  2022-07-31  2022      Q3     July    Vietnam           Asia
#
#                city              product_name     category     storage  ...  \
# 0      Buenos Aires         AirPods (3rd Gen)      AirPods         NaN  ...
# ...

# %% [markdown]
# # 2022 Sum + sum price

# %%
year2022_sum = len (year2022)
year2022_sum_price = round(year2022["unit_price_usd"].sum())

year2022_sum, year2022_sum_price
# Out:
# (3898, 3042749)

# %% [markdown]
# # 2022 | Q1

# %%
Q1_y_2022 = year2022[year2022['quarter'] == 'Q1']

Q1_y_2022.sample(1)
# Out:
#        sale_date  year quarter  month      country  region      city  \
# 6050  2022-03-02  2022      Q1  March  Netherlands  Europe  Nijmegen
#
#                   product_name     category storage  ... currency  \
# 6050  USB-C Woven Charge Cable  Accessories     NaN  ...      EUR
#
#       fx_rate_to_usd  revenue_local_currency  sales_channel  payment_method  \
# 6050            0.92                   48.15    Apple Store     Credit Card
#
#       customer_segment customer_age_group  previous_device_os  \
# 6050        Government              45–54                 NaN
#
#       customer_rating return_status
# 6050              NaN          Kept
#
# [1 rows x 26 columns]

# %%
Q1_y_2022_sum = len (Q1_y_2022)
Q1_y_2022_sum_price = round( Q1_y_2022["unit_price_usd"].sum())

Q1_y_2022_sum, Q1_y_2022_sum_price
# Out:
# (970, 774161)

# %% [markdown]
# # 2022 | Q2

# %%
Q2_y_2022 = year2022[year2022['quarter'] == 'Q2']

Q2_y_2022.sample(1)
# Out:
#        sale_date  year quarter month      country region      city  \
# 7110  2022-06-18  2022      Q2  June  Philippines   Asia  Antipolo
#
#        product_name category storage  ... currency  fx_rate_to_usd  \
# 7110  iPhone 13 Pro   iPhone  128 GB  ...      PHP            56.5
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 7110                 45267.8    Apple Store     Net Banking          Business
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 7110              45–54              iOS 16              4.1          Kept
#
# [1 rows x 26 columns]

# %%
Q2_y_2022_sum = len (Q2_y_2022)
Q2_y_2022_sum_price = round(Q2_y_2022["unit_price_usd"].sum())

Q2_y_2022_sum, Q2_y_2022_sum_price
# Out:
# (946, 729307)

# %% [markdown]
# # 2022 | Q3

# %%
Q3_y_2022 = year2022[year2022['quarter'] == 'Q3']

Q3_y_2022.sample(1)
# Out:
#        sale_date  year quarter   month country  region        city  \
# 9244  2022-08-01  2022      Q3  August   Spain  Europe  Valladolid
#
#      product_name category storage  ... currency  fx_rate_to_usd  \
# 9244  AirPods Max  AirPods     NaN  ...      EUR            0.92
#
#       revenue_local_currency        sales_channel  payment_method  \
# 9244                 1199.25  Authorized Reseller      Debit Card
#
#       customer_segment customer_age_group  previous_device_os  \
# 9244        Individual              35–44                 NaN
#
#       customer_rating return_status
# 9244              NaN          Kept
#
# [1 rows x 26 columns]

# %%
Q3_y_2022_sum = len (Q3_y_2022)
Q3_y_2022_sum_price = round(Q3_y_2022["unit_price_usd"].sum())

Q3_y_2022_sum, Q3_y_2022_sum_price
# Out:
# (978, 782178)

# %% [markdown]
# # 2022 | Q4

# %%
Q4_y_2022 = year2022[year2022['quarter'] == 'Q4']

Q4_y_2022.sample(1)
# Out:
#        sale_date  year quarter    month country         region     city  \
# 1452  2022-10-10  2022      Q4  October  Canada  North America  Calgary
#
#              product_name category storage  ... currency  fx_rate_to_usd  \
# 1452  iPhone SE (3rd Gen)   iPhone  256 GB  ...      CAD            1.36
#
#       revenue_local_currency       sales_channel     payment_method  \
# 1452                  525.04  Online (Apple.com)  EMI / Installment
#
#       customer_segment customer_age_group  previous_device_os  \
# 1452          Business              18–24              iOS 15
#
#       customer_rating return_status
# 1452              NaN          Kept
#
# [1 rows x 26 columns]

# %%
Q4_y_2022_sum = len (Q4_y_2022)
Q4_y_2022_sum_price = round(Q4_y_2022["unit_price_usd"].sum())

Q4_y_2022_sum, Q4_y_2022_sum_price
# Out:
# (1004, 757103)

# %% [markdown]
# # Year 2023

# %%
year2023 = df [df['year'] == 2023]

year2023.sample(1)
# Out:
#         sale_date  year quarter month country       region     city  \
# 10756  2023-05-29  2023      Q2   May     UAE  Middle East  Sharjah
#
#       product_name     category storage  ... currency  fx_rate_to_usd  \
# 10756  Magic Mouse  Accessories     NaN  ...      AED            3.67
#
#        revenue_local_currency    sales_channel  payment_method  \
# 10756                  558.28  Corporate / B2B      Debit Card
#
#        customer_segment customer_age_group  previous_device_os  \
# 10756        Government              45–54                 NaN
#
#        customer_rating return_status
# 10756              4.2          Kept
#
# [1 rows x 26 columns]

# %% [markdown]
# # 2023 sum + sum Price

# %%
year2023_sum = len (year2023)
year2023_sum_price = round(year2023["unit_price_usd"].sum(),  )

year2023_sum, year2023_sum_price
# Out:
# (3735, 3043959)

# %% [markdown]
# # 2023 | Q1

# %%
Q1_y_2023 = year2023[year2023["quarter"] == 'Q1']

Q1_y_2023.sample(1)
# Out:
#       sale_date  year quarter     month    country         region  \
# 106  2023-02-27  2023      Q1  February  Argentina  South America
#
#               city        product_name category     storage  ... currency  \
# 106  Mar del Plata  Mac Pro (M2 Ultra)      Mac  512 GB SSD  ...      ARS
#
#      fx_rate_to_usd  revenue_local_currency       sales_channel  \
# 106           907.0             18262290.81  Online (Apple.com)
#
#      payment_method  customer_segment customer_age_group  previous_device_os  \
# 106       Gift Card        Individual              35–44                 NaN
#
#      customer_rating return_status
# 106              3.4          Kept
#
# [1 rows x 26 columns]

# %%
Q1_y_2023_sum = len (Q1_y_2023)
Q1_y_2023_sum_price = round(Q1_y_2023["unit_price_usd"].sum())

Q1_y_2023_sum, Q1_y_2023_sum_price
# Out:
# (945, 801912)

# %% [markdown]
# # 2023 | Q2

# %%
Q2_y_2023 = year2023[year2023["quarter"] == 'Q2']

Q2_y_2023.sample(1)
# Out:
#        sale_date  year quarter month country  region         city  \
# 9342  2023-06-04  2023      Q2  June  Sweden  Europe  Helsingborg
#
#                   product_name     category storage  ... currency  \
# 9342  Apple Watch SE (2nd Gen)  Apple Watch     NaN  ...      SEK
#
#       fx_rate_to_usd  revenue_local_currency  sales_channel  payment_method  \
# 9342           10.55                 2711.98  Carrier Store            Cash
#
#       customer_segment customer_age_group  previous_device_os  \
# 9342          Business              35–44                 NaN
#
#       customer_rating return_status
# 9342              NaN          Kept
#
# [1 rows x 26 columns]

# %%
Q2_y_2023_sum = len (Q2_y_2023)
Q2_y_2023_sum_price = round(Q2_y_2023["unit_price_usd"].sum())

Q2_y_2023_sum, Q2_y_2023_sum_price
# Out:
# (934, 757829)

# %% [markdown]
# #  2023 | Q3

# %%
Q3_y_2023 = year2023[year2023["quarter"] == 'Q3']

Q3_y_2023.sample(1)
# Out:
#        sale_date  year quarter      month country  region          city  \
# 6731  2023-09-15  2023      Q3  September  Norway  Europe  Kristiansand
#
#                product_name category storage  ... currency  fx_rate_to_usd  \
# 6731  iPad Pro 11-inch (M2)     iPad  256 GB  ...      NOK           10.65
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 6731                27092.32  Carrier Store            Cash        Government
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 6731              35–44                 NaN              4.7          Kept
#
# [1 rows x 26 columns]

# %%
Q3_y_2023_sum = len (Q3_y_2023)
Q3_y_2023_sum_price = round(Q3_y_2023["unit_price_usd"].sum())

Q3_y_2023_sum, Q3_y_2023_sum_price
# Out:
# (920, 730480)

# %% [markdown]
# # 2023 | Q4

# %%
Q4_y_2023 = year2023[year2023["quarter"] == 'Q4']

Q4_y_2023.sample(1)
# Out:
#       sale_date  year quarter    month  country  region  city product_name  \
# 565  2023-10-25  2023      Q4  October  Austria  Europe  Graz    iPhone 13
#
#     category storage  ... currency  fx_rate_to_usd  revenue_local_currency  \
# 565   iPhone  128 GB  ...      EUR            0.92                  615.34
#
#            sales_channel     payment_method  customer_segment  \
# 565  Authorized Reseller  EMI / Installment        Government
#
#     customer_age_group  previous_device_os  customer_rating return_status
# 565              35–44             Android              4.8          Kept
#
# [1 rows x 26 columns]

# %%
Q4_y_2023_sum = len (Q4_y_2023)
Q4_y_2023_sum_price = round( Q4_y_2023["unit_price_usd"].sum())

Q4_y_2023_sum, Q4_y_2023_sum_price
# Out:
# (936, 753738)

# %% [markdown]
# # Year 2024

# %%
year2024 = df [df['year'] == 2024]

year2024.sample(1)
# Out:
#         sale_date  year quarter    month   country region        city  \
# 10220  2024-01-02  2024      Q1  January  Thailand   Asia  Nonthaburi
#
#                product_name     category storage  ... currency  \
# 10220  Apple Watch Series 8  Apple Watch     NaN  ...      THB
#
#        fx_rate_to_usd  revenue_local_currency        sales_channel  \
# 10220            35.2                10262.91  Authorized Reseller
#
#        payment_method  customer_segment customer_age_group  \
# 10220     Net Banking        Government              25–34
#
#        previous_device_os  customer_rating return_status
# 10220                 NaN              4.8          Kept
#
# [1 rows x 26 columns]

# %%
year2024_sum = len (year2024)
year2024_sum_price = round(year2024["unit_price_usd"].sum())

year2024_sum, year2024_sum_price
# Out:
# (3867, 3203581)

# %% [markdown]
# # 2024 | Q1

# %%
Q1_y_2024 = year2024[ year2024["quarter"] == 'Q1']

Q1_y_2024.sample(1)
# Out:
#        sale_date  year quarter    month country         region      city  \
# 1428  2024-01-28  2024      Q1  January  Brazil  South America  São Luís
#
#                   product_name category   storage  ... currency  \
# 1428  MacBook Air 13-inch (M2)      Mac  2 TB SSD  ...      BRL
#
#       fx_rate_to_usd  revenue_local_currency  sales_channel  payment_method  \
# 1428            4.97                10170.51    Apple Store       Gift Card
#
#       customer_segment customer_age_group  previous_device_os  \
# 1428          Business              35–44                 NaN
#
#       customer_rating return_status
# 1428              NaN          Kept
#
# [1 rows x 26 columns]

# %%
Q1_y_2024_sum = len (Q1_y_2024)
Q1_y_2024_sum_price = round(Q1_y_2024["unit_price_usd"].sum())

Q1_y_2024_sum, Q1_y_2024_sum_price
# Out:
# (979, 795100)

# %% [markdown]
# # 2024 | Q2

# %%
Q2_y_2024 = year2024[ year2024["quarter"] == 'Q2']

Q2_y_2024.sample(1)
# Out:
#        sale_date  year quarter  month country  region   city product_name  \
# 9423  2024-04-02  2024      Q2  April  Sweden  Europe  Malmö    iPhone 15
#
#      category storage  ... currency  fx_rate_to_usd  revenue_local_currency  \
# 9423   iPhone  128 GB  ...      SEK           10.55                 8254.95
#
#       sales_channel  payment_method  customer_segment customer_age_group  \
# 9423  Carrier Store            Cash          Business              45–54
#
#       previous_device_os  customer_rating return_status
# 9423            New User              4.4          Kept
#
# [1 rows x 26 columns]

# %%
Q2_y_2024_sum = len (Q2_y_2024)
Q2_y_2024_sum_price = round(Q2_y_2024["unit_price_usd"].sum())

Q2_y_2024_sum, Q2_y_2024_sum_price
# Out:
# (940, 744294)

# %% [markdown]
# # 2024 | Q3

# %%
Q3_y_2024 = year2024[ year2024["quarter"] == 'Q3']

Q3_y_2024.sample(1)
# Out:
#        sale_date  year quarter month country         region         city  \
# 5752  2024-07-16  2024      Q3  July  Mexico  North America  Mexico City
#
#      product_name     category storage  ... currency  fx_rate_to_usd  \
# 5752  Magic Mouse  Accessories     NaN  ...      MXN           17.15
#
#       revenue_local_currency  sales_channel     payment_method  \
# 5752                 3914.83    Apple Store  EMI / Installment
#
#       customer_segment customer_age_group  previous_device_os  \
# 5752        Government              35–44                 NaN
#
#       customer_rating return_status
# 5752              4.7          Kept
#
# [1 rows x 26 columns]

# %%
Q3_y_2024_sum = len (Q3_y_2024)
Q3_y_2024_sum_price = round(Q3_y_2024["unit_price_usd"].sum())

Q3_y_2024_sum, Q3_y_2024_sum_price
# Out:
# (966, 793215)

# %% [markdown]
# # 2024 | Q4

# %%
Q4_y_2024 = year2024[ year2024["quarter"] == 'Q4']

Q4_y_2024.sample(1)
# Out:
#        sale_date  year quarter    month   country         region      city  \
# 2383  2024-10-20  2024      Q4  October  Colombia  South America  Medellín
#
#         product_name category storage  ... currency  fx_rate_to_usd  \
# 2383  iPhone 13 Mini   iPhone  512 GB  ...      COP          3960.0
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 2383               2149369.2    Apple Store      Debit Card          Business
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 2383              18–24              iOS 15              4.8          Kept
#
# [1 rows x 26 columns]

# %%
Q4_y_2024_sum = len (Q4_y_2024)
Q4_y_2024_sum_price = round(Q4_y_2024["unit_price_usd"].sum())

Q4_y_2024_sum, Q4_y_2024_sum_price
# Out:
# (982, 870971)

# %% [markdown]
# # Unit price usd

# %%
All_unit_price = round(df["unit_price_usd"].sum())

All_unit_price
# Out:
# 9290289

# %% [markdown]
# # min Pirce, mean Price, max Price

# %%
All_min_price = round(df["unit_price_usd"].min())
All_mean_price = round(df["unit_price_usd"].mean())
All_max_price = round(df["unit_price_usd"].max())

All_min_price,All_mean_price, All_max_price
# Out:
# (27, 808, 7551)

# %%
# Controll:
year2022_sum_price + year2023_sum_price + year2024_sum_price
# Out:
# 9290289

# %% [markdown]
# # Region

# %%
df.sample(1)
# Out:
#        sale_date  year quarter  month      country   region      city  \
# 6278  2022-04-30  2022      Q2  April  New Zealand  Oceania  Hamilton
#
#            product_name category storage  ... currency  fx_rate_to_usd  \
# 6278  iPhone 13 Pro Max   iPhone  256 GB  ...      NZD            1.63
#
#       revenue_local_currency       sales_channel  payment_method  \
# 6278                 3317.73  Online (Apple.com)       Apple Pay
#
#       customer_segment customer_age_group  previous_device_os  \
# 6278        Government              25–34              iOS 16
#
#       customer_rating return_status
# 6278              NaN      Returned
#
# [1 rows x 26 columns]

# %%
df["region"].unique()
# Out:
# array(['South America', 'Oceania', 'Europe', 'Asia', 'North America',
#        'Africa', 'Europe/Asia', 'Middle East'], dtype=object)

# %% [markdown]
# # South America

# %%
South_America = df[ df["region"]== 'South America']

South_America_sum = round(South_America["unit_price_usd"].sum())

South_America_sum
# Out:
# 737873

# %% [markdown]
# # South America 2022, 2023, 2024 Total Sales

# %%
South_America_2022_sum = round(South_America[ South_America["year"] == 2022]["unit_price_usd"].sum())
South_America_2023_sum = round(South_America[ South_America["year"] == 2023]["unit_price_usd"].sum())
South_America_2024_sum = round(South_America[ South_America["year"] == 2024]["unit_price_usd"].sum())

South_America_2022_sum,  South_America_2023_sum,  South_America_2024_sum
# Out:
# (242149, 244621, 251103)

# %% [markdown]
# # South America 2022, 2023, 2024 Total orders

# %%
South_America_2022_order = South_America[ South_America["year"] == 2022].shape[0]
South_America_2023_order = South_America[ South_America["year"] == 2023].shape[0]
South_America_2024_order = South_America[ South_America["year"] == 2024].shape[0]

South_America_2022_order, South_America_2023_order, South_America_2024_order
# Out:
# (338, 321, 331)

# %% [markdown]
# # Oceania

# %%
Oceania = df[ df["region"]== 'Oceania']

Oceania_sum = df[ df["region"]== 'Oceania'].shape[0]

Oceania_sum
# Out:
# 506

# %%
Oceania_2022_sum = round(Oceania[ Oceania["year"] == 2022]["unit_price_usd"].sum())
Oceania_2023_sum = round(Oceania[ Oceania["year"] == 2023]["unit_price_usd"].sum())
Oceania_2024_sum = round(Oceania[ Oceania["year"] == 2024]["unit_price_usd"].sum())

Oceania_2022_sum,  Oceania_2023_sum,  Oceania_2024_sum
# Out:
# (168654, 114773, 122204)

# %%
Oceania_2022_order = Oceania[ Oceania["year"] == 2022].shape[0]
Oceania_2023_order = Oceania[ Oceania["year"] == 2023].shape[0]
Oceania_2024_order = Oceania[ Oceania["year"] == 2024].shape[0]

Oceania_2022_order, Oceania_2023_order, Oceania_2024_order
# Out:
# (189, 159, 158)

# %% [markdown]
# # Europe

# %%
Europe = df[ df["region"]== 'Europe']

Europe_sum = df[ df["region"]== 'Europe'].shape[0]

Europe_sum
# Out:
# 3898

# %%
Europe_2022_sum = round(Europe[ Europe["year"] == 2022]["unit_price_usd"].sum())
Europe_2023_sum = round(Europe[ Europe["year"] == 2023]["unit_price_usd"].sum())
Europe_2024_sum = round(Europe[ Europe["year"] == 2024]["unit_price_usd"].sum())

Europe_2022_sum,  Europe_2023_sum,  Europe_2024_sum
# Out:
# (1037820, 1061268, 1083544)

# %%
Europe_2022_oder = Europe[ Europe["year"] == 2022].shape[0]
Europe_2023_oder = Europe[ Europe["year"] == 2023].shape[0]
Europe_2024_oder = Europe[ Europe["year"] == 2024].shape[0]

Europe_2022_oder, Europe_2023_oder, Europe_2024_oder
# Out:
# (1281, 1307, 1310)

# %% [markdown]
# # Asia

# %%
Asia = df[ df["region"]== 'Asia']

Asia_sum = df[ df["region"]== 'Asia'].shape[0]

Asia_sum
# Out:
# 3435

# %%
Asia_2022_sum = round(Asia[ Asia["year"] == 2022]["unit_price_usd"].sum())
Asia_2023_sum = round(Asia[ Asia["year"] == 2023]["unit_price_usd"].sum())
Asia_2024_sum = round(Asia[ Asia["year"] == 2024]["unit_price_usd"].sum())

Asia_2022_sum,  Asia_2023_sum,  Asia_2024_sum
# Out:
# (886627, 965785, 973025)

# %%
Asia_2022_order = Asia[ Asia["year"] == 2022].shape[0]
Asia_2023_order = Asia[ Asia["year"] == 2023].shape[0]
Asia_2024_order = Asia[ Asia["year"] == 2024].shape[0]

Asia_2022_order, Asia_2023_order, Asia_2024_order
# Out:
# (1156, 1138, 1141)

# %% [markdown]
# # North America

# %%
North_America = df[ df["region"]== 'North America']
North_America_sum = df[ df["region"]== 'North America'].shape[0]

North_America_sum
# Out:
# 762

# %%
North_America_2022_sum = round(North_America[ North_America["year"] == 2022]["unit_price_usd"].sum())
North_America_2023_sum = round(North_America[ North_America["year"] == 2023]["unit_price_usd"].sum())
North_America_2024_sum = round(North_America[ North_America["year"] == 2024]["unit_price_usd"].sum())

North_America_2022_sum,  North_America_2023_sum,  North_America_2024_sum
# Out:
# (217325, 198719, 203137)

# %%
North_America_2022_order = North_America[ North_America["year"] == 2022].shape[0]
North_America_2023_order = North_America[ North_America["year"] == 2023].shape[0]
North_America_2024_order = North_America[ North_America["year"] == 2024].shape[0]

North_America_2022_order, North_America_2023_order, North_America_2024_order
# Out:
# (271, 237, 254)

# %% [markdown]
# # Africa

# %%
Africa = df[ df["region"]== 'Africa']

Africa_sum = df[ df["region"]== 'Africa'].shape[0]

Africa_sum
# Out:
# 943

# %%
Africa_2022_sum = round(Africa[ Africa["year"] == 2022]["unit_price_usd"].sum())
Africa_2023_sum = round(Africa[ Africa["year"] == 2023]["unit_price_usd"].sum())
Africa_2024_sum = round(Africa[ Africa["year"] == 2024]["unit_price_usd"].sum())

Africa_2022_sum,  Africa_2023_sum,  Africa_2024_sum
# Out:
# (243095, 235609, 265552)

# %%
Africa_2022_order = Africa[ Africa["year"] == 2022].shape[0]
Africa_2023_order = Africa[ Africa["year"] == 2023].shape[0]
Africa_2024_order = Africa[ Africa["year"] == 2024].shape[0]

Africa_2022_order, Africa_2023_order, Africa_2024_order
# Out:
# (325, 280, 338)

# %% [markdown]
# # Europe/Asia

# %%
Europe_Asia = df[ df["region"]== 'Europe/Asia']

Europe_Asia_sum = df[ df["region"]== 'Europe/Asia'].shape[0]

Europe_Asia_sum
# Out:
# 480

# %%
Europe_Asia_2022_sum = round(Europe_Asia[ Europe_Asia["year"] == 2022]["unit_price_usd"].sum())
Europe_Asia_2023_sum = round(Europe_Asia[ Europe_Asia["year"] == 2023]["unit_price_usd"].sum())
Europe_Asia_2024_sum = round(Europe_Asia[ Europe_Asia["year"] == 2024]["unit_price_usd"].sum())

Europe_Asia_2022_sum,  Europe_Asia_2023_sum,  Europe_Asia_2024_sum
# Out:
# (110360, 107372, 153189)

# %%
Europe_Asia_2022_order = Europe_Asia[ Europe_Asia["year"] == 2022].shape[0]
Europe_Asia_2023_order = Europe_Asia[ Europe_Asia["year"] == 2023].shape[0]
Europe_Asia_2024_order = Europe_Asia[ Europe_Asia["year"] == 2024].shape[0]

Europe_Asia_2022_order, Europe_Asia_2023_order, Europe_Asia_2024_order
# Out:
# (162, 151, 167)

# %% [markdown]
# # Middle East

# %%
Middle_East = df[ df["region"]== 'Middle East']

Middle_East_sum = df[ df["region"]== 'Middle East'].shape[0]

Middle_East_sum
# Out:
# 486

# %%
Middle_East_2022_sum = round(Middle_East[ Middle_East["year"] == 2022]["unit_price_usd"].sum())
Middle_East_2023_sum = round(Middle_East[ Middle_East["year"] == 2023]["unit_price_usd"].sum())
Middle_East_2024_sum = round(Middle_East[ Middle_East["year"] == 2024]["unit_price_usd"].sum())

Middle_East_2022_sum,  Middle_East_2023_sum,  Middle_East_2024_sum
# Out:
# (136719, 115811, 151826)

# %%
Middle_East_2022_order = Middle_East[ Middle_East["year"] == 2022].shape[0]
Middle_East_2023_order = Middle_East[ Middle_East["year"] == 2023].shape[0]
Middle_East_2024_order = Middle_East[ Middle_East["year"] == 2024].shape[0]

Middle_East_2022_order, Middle_East_2023_order, Middle_East_2024_order
# Out:
# (176, 142, 168)

# %% [markdown]
# # All Apple Categories

# %%
df["category"].unique()
# Out:
# array(['AirPods', 'Accessories', 'Apple Watch', 'Mac', 'iPhone', 'iPad'],
#       dtype=object)

# %%
All_category = df['category'].nunique()

All_category
# Out:
# 6

# %% [markdown]
# # AirPods

# %%
AirPods = df[ df["category"] == 'AirPods']

AirPods_sum = df[ df["category"] == 'AirPods'].shape[0]

AirPods_sum
# Out:
# 1063

# %%
AirPods_2022 = AirPods[ AirPods['year'] == 2022].shape[0]
AirPods_2023 = AirPods[ AirPods['year'] == 2023].shape[0]
AirPods_2024 = AirPods[ AirPods['year'] == 2024].shape[0]

AirPods_2022, AirPods_2023, AirPods_2024
# Out:
# (367, 364, 332)

# %% [markdown]
# # Accessories

# %%
Accessories = df[ df["category"] == 'Accessories']

Accessories_sum = df[ df["category"] == 'Accessories'].shape[0]

Accessories_sum
# Out:
# 2615

# %%
Accessories_2022 = Accessories[ Accessories['year'] == 2022].shape[0]
Accessories_2023 = Accessories[ Accessories['year'] == 2023].shape[0]
Accessories_2024 = Accessories[ Accessories['year'] == 2024].shape[0]

Accessories_2022, Accessories_2023, Accessories_2024
# Out:
# (899, 837, 879)

# %% [markdown]
# # Apple Watch

# %%
Apple_Watch = df[ df["category"] == 'Apple Watch']

Apple_Watch_sum = df[ df["category"] == 'Apple Watch'].shape[0]

Apple_Watch_sum
# Out:
# 1126

# %%
Apple_Watch_2022 = Apple_Watch[ Apple_Watch['year'] == 2022].shape[0]
Apple_Watch_2023 = Apple_Watch[ Apple_Watch['year'] == 2023].shape[0]
Apple_Watch_2024 = Apple_Watch[ Apple_Watch['year'] == 2024].shape[0]

Apple_Watch_2022, Apple_Watch_2023, Apple_Watch_2024
# Out:
# (368, 361, 397)

# %% [markdown]
# # Mac

# %%
Mac = df[ df["category"] == 'Mac']

Mac_sum = df[ df["category"] == 'Mac'].shape[0]

Mac_sum
# Out:
# 1873

# %%
Mac_2022 = Mac[ Mac['year'] == 2022].shape[0]
Mac_2023 = Mac[ Mac['year'] == 2023].shape[0]
Mac_2024 = Mac[ Mac['year'] == 2024].shape[0]

Mac_2022, Mac_2023, Mac_2024
# Out:
# (607, 633, 633)

# %% [markdown]
# # iPhone

# %%
iPhone = df[ df["category"] == 'iPhone']

iPhone_sum = df[ df["category"] == 'iPhone'].shape[0]

iPhone_sum
# Out:
# 3444

# %%
iPhone_2022 = iPhone[ iPhone['year'] == 2022].shape[0]
iPhone_2023 = iPhone[ iPhone['year'] == 2023].shape[0]
iPhone_2024 = iPhone[ iPhone['year'] == 2024].shape[0]

iPhone_2022, iPhone_2023, iPhone_2024
# Out:
# (1166, 1116, 1162)

# %% [markdown]
# # iPad

# %%
iPad = df[ df["category"] == 'iPad']

iPad_sum = df[ df["category"] == 'iPad'].shape[0]

iPad_sum
# Out:
# 1379

# %%
AirPods_2022 = AirPods[ AirPods['year'] == 2022].shape[0]
AirPods_2023 = AirPods[ AirPods['year'] == 2023].shape[0]
AirPods_2024 = AirPods[ AirPods['year'] == 2024].shape[0]

AirPods_2022, AirPods_2023, AirPods_2024
# Out:
# (367, 364, 332)

# %% [markdown]
# # Payment Method

# %%
df["payment_method"].unique()
# Out:
# array(['Cash', 'Debit Card', 'Credit Card', 'Net Banking', 'Gift Card',
#        'Apple Pay', 'EMI / Installment'], dtype=object)

# %% [markdown]
# # Cash

# %%
Cash = df[ df["payment_method"]== 'Cash']

Cash.sample(1)
# Out:
#         sale_date  year quarter   month        country         region    city  \
# 11056  2024-08-25  2024      Q3  August  United States  North America  Austin
#
#          product_name     category storage  ... currency  fx_rate_to_usd  \
# 11056  Magic Keyboard  Accessories     NaN  ...      USD             1.0
#
#        revenue_local_currency        sales_channel  payment_method  \
# 11056                    97.7  Authorized Reseller            Cash
#
#        customer_segment customer_age_group  previous_device_os  \
# 11056         Education                55+                 NaN
#
#        customer_rating return_status
# 11056              NaN          Kept
#
# [1 rows x 26 columns]

# %% [markdown]
# # Cash orders and Sales

# %%
Cash_orders = Cash[ Cash["year"] == 2022].shape[0]
Cash_sum_sales = round(Cash[ Cash["year"] == 2022]["unit_price_usd"].sum())

Cash_orders, Cash_sum_sales
# Out:
# (514, 417445)

# %% [markdown]
# # Debit Card

# %%
Debit_Card = df[ df["payment_method"]== 'Debit Card']

Debit_Card.sample(1)
# Out:
#        sale_date  year quarter    month      country  region   city  \
# 9560  2023-01-22  2023      Q1  January  Switzerland  Europe  Basel
#
#      product_name category storage  ... currency  fx_rate_to_usd  \
# 9560  AirPods Max  AirPods     NaN  ...      CHF            0.88
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 9560                  938.15    Apple Store      Debit Card        Government
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 9560              18–24                 NaN              NaN          Kept
#
# [1 rows x 26 columns]

# %%
Debit_Card_orders = Debit_Card[ Debit_Card["year"] == 2022].shape[0]
Debit_Card_sum_sales = round(Debit_Card[ Debit_Card["year"] == 2022]["unit_price_usd"].sum())

Debit_Card_orders, Debit_Card_sum_sales
# Out:
# (527, 426337)

# %% [markdown]
# # Credit Card

# %%
Credit_Card = df[ df["payment_method"]== 'Credit Card']

Credit_Card.sample(1)
# Out:
#        sale_date  year quarter    month country         region      city  \
# 1867  2022-10-18  2022      Q4  October   Chile  South America  Santiago
#
#      product_name category storage  ... currency  fx_rate_to_usd  \
# 1867    iPhone 13   iPhone  256 GB  ...      CLP           960.0
#
#       revenue_local_currency    sales_channel  payment_method  \
# 1867                687484.8  Corporate / B2B     Credit Card
#
#       customer_segment customer_age_group  previous_device_os  \
# 1867        Individual              45–54               Other
#
#       customer_rating return_status
# 1867              3.3          Kept
#
# [1 rows x 26 columns]

# %%
Credit_Card_orders = Credit_Card[ Credit_Card["year"] == 2022].shape[0]
Credit_Card_sum_sales = round(Credit_Card[ Credit_Card["year"] == 2022]["unit_price_usd"].sum())

Credit_Card_orders, Credit_Card_sum_sales
# Out:
# (589, 426513)

# %% [markdown]
# # Net Banking

# %%
Net_Banking = df[ df["payment_method"]== 'Net Banking']

Net_Banking.sample(1)
# Out:
#         sale_date  year quarter      month  country region      city  \
# 11282  2022-09-23  2022      Q3  September  Vietnam   Asia  Bien Hoa
#
#               product_name     category storage  ... currency  fx_rate_to_usd  \
# 11282  Apple Watch Ultra 2  Apple Watch     NaN  ...      VND         24500.0
#
#        revenue_local_currency  sales_channel  payment_method  \
# 11282              20210295.0    Apple Store     Net Banking
#
#        customer_segment customer_age_group  previous_device_os  \
# 11282        Government              45–54                 NaN
#
#        customer_rating return_status
# 11282              4.7          Kept
#
# [1 rows x 26 columns]

# %%
Net_Banking_orders = Net_Banking[ Net_Banking["year"] == 2022].shape[0]
Net_Banking_sum_sales = round(Net_Banking[ Net_Banking["year"] == 2022]["unit_price_usd"].sum())

Net_Banking_orders, Net_Banking_sum_sales
# Out:
# (577, 450436)

# %% [markdown]
# # Gift Card

# %%
Gift_Card = df[ df["payment_method"]== 'Gift Card']

Gift_Card.sample(1)
# Out:
#        sale_date  year quarter   month country  region       city  \
# 9467  2023-08-15  2023      Q3  August  Sweden  Europe  Stockholm
#
#              product_name category storage  ... currency  fx_rate_to_usd  \
# 9467  iPhone SE (3rd Gen)   iPhone   64 GB  ...      SEK           10.55
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 9467                 9714.02    Apple Store       Gift Card        Individual
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 9467              25–34            New User              4.7          Kept
#
# [1 rows x 26 columns]

# %%
Gift_Card_orders = Gift_Card[ Gift_Card["year"] == 2022].shape[0]
Gift_Card_sum_sales = round(Gift_Card[ Gift_Card["year"] == 2022]["unit_price_usd"].sum())

Gift_Card_orders, Gift_Card_sum_sales
# Out:
# (574, 449320)

# %% [markdown]
# # Apple Pay

# %%
Apple_Pay = df[ df["payment_method"]== 'Apple Pay']

Apple_Pay.sample(1)
# Out:
#        sale_date  year quarter     month country region       city  \
# 3962  2024-12-17  2024      Q4  December   India   Asia  Ahmedabad
#
#            product_name category storage  ... currency  fx_rate_to_usd  \
# 3962  iPhone 13 Pro Max   iPhone    1 TB  ...      INR            83.5
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 3962               184533.33    Apple Store       Apple Pay          Business
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 3962              45–54              iOS 15              NaN          Kept
#
# [1 rows x 26 columns]

# %%
Apple_Pay_orders = Apple_Pay[ Apple_Pay["year"] == 2022].shape[0]
Apple_Pay_sum_sales = round(Apple_Pay[ Apple_Pay["year"] == 2022]["unit_price_usd"].sum())

Apple_Pay_orders, Apple_Pay_sum_sales
# Out:
# (558, 416972)

# %% [markdown]
# # EMI / Installment

# %%
EMI_Installment = df[ df["payment_method"]== 'EMI / Installment']

EMI_Installment.sample(1)
# Out:
#        sale_date  year quarter month  country  region     city  \
# 4499  2024-06-12  2024      Q2  June  Ireland  Europe  Dundalk
#
#                   product_name category     storage  ... currency  \
# 4499  MacBook Air 15-inch (M2)      Mac  512 GB SSD  ...      EUR
#
#       fx_rate_to_usd  revenue_local_currency    sales_channel  \
# 4499            0.92                  1048.2  Corporate / B2B
#
#          payment_method  customer_segment customer_age_group  \
# 4499  EMI / Installment         Education              25–34
#
#       previous_device_os  customer_rating return_status
# 4499                 NaN              4.6          Kept
#
# [1 rows x 26 columns]

# %%
EMI_Installment_orders = EMI_Installment[ EMI_Installment["year"] == 2022].shape[0]
EMI_Installment_sum_sales = round(EMI_Installment[ EMI_Installment["year"] == 2022]["unit_price_usd"].sum())

EMI_Installment_orders, EMI_Installment_sum_sales
# Out:
# (559, 455726)

# %% [markdown]
# # Customer segment
# - 'Government'
# - 'Business'
# - 'Individual'
# - 'Education

# %%
df["customer_segment"].unique()
# Out:
# array(['Government', 'Business', 'Individual', 'Education'], dtype=object)

# %% [markdown]
# # Government

# %%
Government = df[ df["customer_segment"] == 'Government']

Government.sample(1)
# Out:
#       sale_date  year quarter month    country         region   city  \
# 201  2022-05-27  2022      Q2   May  Argentina  South America  Salta
#
#           product_name category storage  ... currency  fx_rate_to_usd  \
# 201  iPhone 15 Pro Max   iPhone   64 GB  ...      ARS           907.0
#
#      revenue_local_currency         sales_channel  payment_method  \
# 201              2190477.56  Third-Party Retailer     Net Banking
#
#      customer_segment customer_age_group  previous_device_os  customer_rating  \
# 201        Government              25–34             Android              3.9
#
#     return_status
# 201          Kept
#
# [1 rows x 26 columns]

# %% [markdown]
# # Government Order and Price sales

# %%
Government_sum_price = round(Government["unit_price_usd"].sum())

Government_orders = Government.shape[0]

Government_orders, Government_sum_price
# Out:
# (2892, 2258718)

# %% [markdown]
# # Government 2022, 2023, 2024

# %%
Government_2022 = round(Government[ Government["year"] == 2022]["unit_price_usd"].sum())
Government_2023 = round(Government[ Government["year"] == 2023]["unit_price_usd"].sum())
Government_2024 = round(Government[ Government["year"] == 2024]["unit_price_usd"].sum())

Government_2022, Government_2023,  Government_2024
# Out:
# (709077, 753362, 796279)

# %% [markdown]
# # Business

# %%
Business = df[ df["customer_segment"] == 'Business']

Business.sample(1)
# Out:
#       sale_date  year quarter     month    country   region      city  \
# 333  2024-12-07  2024      Q4  December  Australia  Oceania  Canberra
#
#              product_name     category storage  ... currency  fx_rate_to_usd  \
# 333  Apple Watch Series 9  Apple Watch     NaN  ...      AUD            1.53
#
#      revenue_local_currency        sales_channel  payment_method  \
# 333                  603.68  Authorized Reseller      Debit Card
#
#      customer_segment customer_age_group  previous_device_os  customer_rating  \
# 333          Business              18–24                 NaN              3.1
#
#     return_status
# 333          Kept
#
# [1 rows x 26 columns]

# %%
Business_sum_price = round(Business["unit_price_usd"].sum())

Business_orders = Business.shape[0]

Business_orders, Business_sum_price
# Out:
# (2839, 2326487)

# %%
Business_2022 = round(Business[ Business["year"] == 2022]["unit_price_usd"].sum())
Business_2023 = round(Business[ Business["year"] == 2023]["unit_price_usd"].sum())
Business_2024 = round(Business[ Business["year"] == 2024]["unit_price_usd"].sum())

Business_2022, Business_2023, Business_2024
# Out:
# (766198, 743128, 817161)

# %% [markdown]
# # Individual

# %%
Individual = df[ df["customer_segment"] == 'Individual']

Individual.sample(1)
# Out:
#        sale_date  year quarter  month country         region  city  \
# 5725  2024-03-28  2024      Q1  March  Mexico  North America  León
#
#        product_name category storage  ... currency  fx_rate_to_usd  \
# 5725  iPhone 15 Pro   iPhone    1 TB  ...      MXN           17.15
#
#       revenue_local_currency        sales_channel  payment_method  \
# 5725                 16403.8  Authorized Reseller            Cash
#
#       customer_segment customer_age_group  previous_device_os  \
# 5725        Individual                55+            New User
#
#       customer_rating return_status
# 5725              NaN          Kept
#
# [1 rows x 26 columns]

# %%
Individual_sum_price = round(Individual["unit_price_usd"].sum())

Individual_orders = Individual.shape[0]

Individual_orders, Individual_sum_price
# Out:
# (2885, 2266834)

# %%
Individual_2022 = round(Individual[ Individual["year"] == 2022]["unit_price_usd"].sum())
Individual_2023 = round(Individual[ Individual["year"] == 2023]["unit_price_usd"].sum())
Individual_2024 = round(Individual[ Individual["year"] == 2024]["unit_price_usd"].sum())

Individual_2022, Individual_2023, Individual_2024
# Out:
# (761488, 727601, 777745)

# %% [markdown]
# # Education

# %%
Education = df[ df["customer_segment"] == 'Education']

Education.sample(1)
# Out:
#        sale_date  year quarter    month country  region   city  \
# 9205  2024-10-20  2024      Q4  October   Spain  Europe  Palma
#
#         product_name category storage  ... currency  fx_rate_to_usd  \
# 9205  iPhone 15 Plus   iPhone  128 GB  ...      EUR            0.92
#
#       revenue_local_currency         sales_channel  payment_method  \
# 9205                   802.7  Third-Party Retailer      Debit Card
#
#       customer_segment customer_age_group  previous_device_os  \
# 9205         Education              18–24               Other
#
#       customer_rating return_status
# 9205              3.6          Kept
#
# [1 rows x 26 columns]

# %%
Education_sum_price = round(Education["unit_price_usd"].sum())

Education_orders = Education.shape[0]

Education_orders, Education_sum_price
# Out:
# (2884, 2438250)

# %%
Education_2022 = round(Education[ Education["year"] == 2022]["unit_price_usd"].sum())
Education_2023 = round(Education[ Education["year"] == 2023]["unit_price_usd"].sum())
Education_2024 = round(Education[ Education["year"] == 2024]["unit_price_usd"].sum())

Education_2022, Education_2023, Education_2024
# Out:
# (805986, 819868, 812396)

# %% [markdown]
# # Customer age group
# - '45–54'
# - '18–24'
# - '55+'
# - '35–44'
# -  '25–34'

# %%
df["customer_age_group"].unique()
# Out:
# array(['45–54', '18–24', '55+', '35–44', '25–34'], dtype=object)

# %% [markdown]
# # Customer 18-24

# %%
Customer_18_24 = df[ df["customer_age_group"] == '18–24']

Customer_18_24.sample(1)
# Out:
#        sale_date  year quarter    month      country  region    city  \
# 9696  2022-01-07  2022      Q1  January  Switzerland  Europe  Lugano
#
#         product_name category storage  ... currency  fx_rate_to_usd  \
# 9696  iPhone 14 Plus   iPhone    1 TB  ...      CHF            0.88
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 9696                  724.24    Apple Store       Apple Pay        Government
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 9696              18–24              iOS 15              3.9          Kept
#
# [1 rows x 26 columns]

# %%
Customer_18_24_y_2022_sales = round(Customer_18_24[ Customer_18_24["year"] == 2022]["unit_price_usd"].sum())
Customer_18_24_y_2023_sales = round(Customer_18_24[ Customer_18_24["year"] == 2023]["unit_price_usd"].sum())
Customer_18_24_y_2024_sales = round(Customer_18_24[ Customer_18_24["year"] == 2024]["unit_price_usd"].sum())

Customer_18_24_y_2022_sales, Customer_18_24_y_2023_sales, Customer_18_24_y_2024_sales
# Out:
# (569743, 595582, 621623)

# %%
Customer_18_24_y_2022_orders = Customer_18_24[ Customer_18_24["year"] == 2022].shape[0]
Customer_18_24_y_2023_orders = Customer_18_24[ Customer_18_24["year"] == 2024].shape[0]
Customer_18_24_y_2024_orders = Customer_18_24[ Customer_18_24["year"] == 2024].shape[0]

Customer_18_24_y_2022_orders, Customer_18_24_y_2023_orders, Customer_18_24_y_2024_orders
# Out:
# (792, 770, 770)

# %% [markdown]
# # Customer 25–34

# %%
Customer_25_34 = df[ df["customer_age_group"] == '25–34']

Customer_25_34.sample(1)
# Out:
#        sale_date  year quarter month  country  region       city  \
# 3569  2024-05-13  2024      Q2   May  Germany  Europe  Frankfurt
#
#            product_name     category storage  ... currency  fx_rate_to_usd  \
# 3569  HomePod (2nd Gen)  Accessories     NaN  ...      EUR            0.92
#
#       revenue_local_currency        sales_channel  payment_method  \
# 3569                  563.85  Authorized Reseller       Apple Pay
#
#       customer_segment customer_age_group  previous_device_os  \
# 3569        Individual              25–34                 NaN
#
#       customer_rating return_status
# 3569              3.3          Kept
#
# [1 rows x 26 columns]

# %%
Customer_25_34_y_2022_sales = round(Customer_25_34[ Customer_25_34["year"] == 2022]["unit_price_usd"].sum())
Customer_25_34_y_2023_sales = round(Customer_25_34[ Customer_25_34["year"] == 2023]["unit_price_usd"].sum())
Customer_25_34_y_2024_sales = round(Customer_25_34[ Customer_25_34["year"] == 2024]["unit_price_usd"].sum())

Customer_25_34_y_2022_sales, Customer_25_34_y_2023_sales, Customer_25_34_y_2024_sales
# Out:
# (638198, 637193, 716084)

# %%
Customer_25_34_y_2022_orders = Customer_25_34[ Customer_25_34["year"] == 2022].shape[0]
Customer_25_34_y_2023_orders = Customer_25_34[ Customer_25_34["year"] == 2024].shape[0]
Customer_25_34_y_2024_orders = Customer_25_34[ Customer_25_34["year"] == 2024].shape[0]

Customer_25_34_y_2022_orders, Customer_25_34_y_2023_orders, Customer_25_34_y_2024_orders
# Out:
# (795, 811, 811)

# %% [markdown]
# # Customer 35–44

# %%
Customer_35_44 = df[ df["customer_age_group"] == '35–44']

Customer_35_44.sample(1)
# Out:
#       sale_date  year quarter    month    country         region     city  \
# 158  2022-01-05  2022      Q1  January  Argentina  South America  Rosario
#
#       product_name category storage  ... currency  fx_rate_to_usd  \
# 158  iPad Air (M1)     iPad   64 GB  ...      ARS           907.0
#
#      revenue_local_currency         sales_channel  payment_method  \
# 158               535102.79  Third-Party Retailer       Apple Pay
#
#      customer_segment customer_age_group  previous_device_os  customer_rating  \
# 158          Business              35–44                 NaN              3.2
#
#     return_status
# 158          Kept
#
# [1 rows x 26 columns]

# %%
Customer_35_44_y_2022_sales = round(Customer_35_44[ Customer_35_44["year"] == 2022]["unit_price_usd"].sum())
Customer_35_44_y_2023_sales = round(Customer_35_44[ Customer_35_44["year"] == 2023]["unit_price_usd"].sum())
Customer_35_44_y_2024_sales = round(Customer_35_44[ Customer_35_44["year"] == 2024]["unit_price_usd"].sum())

Customer_35_44_y_2022_sales, Customer_35_44_y_2023_sales, Customer_35_44_y_2024_sales
# Out:
# (622888, 582164, 659826)

# %%
Customer_35_44_y_2022_orders = Customer_35_44[ Customer_35_44["year"] == 2022].shape[0]
Customer_35_44_y_2023_orders = Customer_35_44[ Customer_35_44["year"] == 2024].shape[0]
Customer_35_44_y_2024_orders = Customer_35_44[ Customer_35_44["year"] == 2024].shape[0]

Customer_35_44_y_2022_orders, Customer_35_44_y_2023_orders, Customer_35_44_y_2024_orders
# Out:
# (766, 781, 781)

# %% [markdown]
# # Customer 45–54

# %%
Customer_45_54 = df[ df["customer_age_group"] == '45–54']

Customer_45_54.sample(1)
# Out:
#        sale_date  year quarter  month country  region       city  \
# 9394  2024-03-04  2024      Q1  March  Sweden  Europe  Linköping
#
#       product_name     category storage  ... currency  fx_rate_to_usd  \
# 9394  HomePod mini  Accessories     NaN  ...      SEK           10.55
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 9394                 1072.83    Apple Store      Debit Card        Government
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 9394              45–54                 NaN              3.3          Kept
#
# [1 rows x 26 columns]

# %%
Customer_45_54_y_2022_sales = round(Customer_45_54[ Customer_45_54["year"] == 2022]["unit_price_usd"].sum())
Customer_45_54_y_2023_sales = round(Customer_45_54[ Customer_45_54["year"] == 2023]["unit_price_usd"].sum())
Customer_45_54_y_2024_sales = round(Customer_45_54[ Customer_45_54["year"] == 2024]["unit_price_usd"].sum())

Customer_45_54_y_2022_sales, Customer_45_54_y_2023_sales, Customer_45_54_y_2024_sales
# Out:
# (597727, 587410, 621417)

# %%
Customer_45_54_y_2022_orders = Customer_45_54[ Customer_45_54["year"] == 2022].shape[0]
Customer_45_54_y_2023_orders = Customer_45_54[ Customer_45_54["year"] == 2024].shape[0]
Customer_45_54_y_2024_orders = Customer_45_54[ Customer_45_54["year"] == 2024].shape[0]

Customer_45_54_y_2022_orders, Customer_45_54_y_2023_orders, Customer_45_54_y_2024_orders
# Out:
# (783, 770, 770)

# %% [markdown]
# # Customer 55+

# %%
Customer_55 = df[ df["customer_age_group"] == '55+']

Customer_55.sample(1)
# Out:
#        sale_date  year quarter     month    country region       city  \
# 8503  2024-02-26  2024      Q1  February  Singapore   Asia  Singapore
#
#        product_name category storage  ... currency  fx_rate_to_usd  \
# 8503  iPhone 14 Pro   iPhone    1 TB  ...      SGD            1.34
#
#       revenue_local_currency  sales_channel  payment_method  customer_segment  \
# 8503                  1294.6  Carrier Store     Credit Card        Government
#
#      customer_age_group  previous_device_os  customer_rating return_status
# 8503                55+               Other              4.3          Kept
#
# [1 rows x 26 columns]

# %%
Customer_55_y_2022_sales = round(Customer_55[ Customer_55["year"] == 2022]["unit_price_usd"].sum())
Customer_55_y_2023_sales = round(Customer_55[ Customer_55["year"] == 2023]["unit_price_usd"].sum())
Customer_55_y_2024_sales = round(Customer_55[ Customer_55["year"] == 2024]["unit_price_usd"].sum())

Customer_55_y_2022_sales, Customer_55_y_2023_sales, Customer_55_y_2024_sales
# Out:
# (614192, 641610, 584631)

# %%
Customer_55_y_2022_orders = Customer_55[ Customer_55["year"] == 2022].shape[0]
Customer_55_y_2023_orders = Customer_55[ Customer_55["year"] == 2024].shape[0]
Customer_55_y_2024_orders = Customer_55[ Customer_55["year"] == 2024].shape[0]

Customer_55_y_2022_orders, Customer_55_y_2023_orders, Customer_55_y_2024_orders
# Out:
# (762, 735, 735)

# %%
os.listdir("../data/cleaned_data")
# Out:
# ['cleaned_data.csv']

# %%
df.to_csv("../data/cleaned_data/cleaned_data.csv")
